# %%
from fredapi import Fred
import plotly
import pandas as pd
import numpy as np
import os
from dotenv import load_dotenv

load_dotenv()
# Open DART API KEY 설정
fred_api_key= os.environ.get("fred_key")

fred = Fred(api_key=fred_api_key)

# %%
fred.search('unemployment').T
# Out:
# series id                                                             UNRATE  \
# id                                                                    UNRATE
# realtime_start                                           2022-10-16 00:00:00
# realtime_end                                             2022-10-16 00:00:00
# title                                                      Unemployment Rate
# observation_start                                        1948-01-01 00:00:00
# observation_end                                          2022-09-01 00:00:00
# frequency                                                            Monthly
# frequency_short                                                            M
# units                                                                Percent
# units_short                                                                %
# seasonal_adjustment                                      Seasonally Adjusted
# seasonal_adjustment_short                                                 SA
# last_updated                                       2022-10-07 07:44:01-05:00
# popularity                                                                94
# notes                      The unemployment rate represents the number of...
#
# series id                                                          UNRATENSA  \
# id                                                                 UNRATENSA
# realtime_start                                           2022-10-16 00:00:00
# realtime_end                                             2022-10-16 00:00:00
# title                                                      Unemployment Rate
# observation_start                                        1948-01-01 00:00:00
# observation_end                                          2022-09-01 00:00:00
# frequency                                                            Monthly
# frequency_short                                                            M
# units                                                                Percent
# units_short                                                                %
# seasonal_adjustment                                  Not Seasonally Adjusted
# seasonal_adjustment_short                                                NSA
# last_updated                                       2022-10-07 07:43:02-05:00
# popularity                                                                63
# notes                      The unemployment rate represents the number of...
#
# series id                                                               NROU  \
# id                                                                      NROU
# realtime_start                                           2022-10-16 00:00:00
# realtime_end                                             2022-10-16 00:00:00
# title                                       Noncyclical Rate of Unemployment
# observation_start                                        1949-01-01 00:00:00
# observation_end                                          2032-10-01 00:00:00
# frequency                                                          Quarterly
# frequency_short                                                            Q
# units                                                                Percent
# units_short                                                                %
# seasonal_adjustment                                  Not Seasonally Adjusted
# seasonal_adjustment_short                                                NSA
# last_updated                                       2022-05-26 13:45:04-05:00
# popularity                                                                73
# notes                      Starting with the July, 2021 report: An Update...
#
# series id                                                           UNEMPLOY  \
# id                                                                  UNEMPLOY
# realtime_start                                           2022-10-16 00:00:00
# realtime_end                                             2022-10-16 00:00:00
# title                                                     Unemployment Level
# observation_start                                        1948-01-01 00:00:00
# observation_end                                          2022-09-01 00:00:00
# frequency                                                            Monthly
# frequency_short                                                            M
# units                                                   Thousands of Persons
# units_short                                                Thous. of Persons
# seasonal_adjustment                                      Seasonally Adjusted
# seasonal_adjustment_short                                                 SA
# last_updated                                       2022-10-07 07:44:02-05:00
# popularity                                                                70
# notes                      The series comes from the 'Current Population ...
#
# series id                                                               CCSA  \
# id                                                                      CCSA
# realtime_start                                           2022-10-16 00:00:00
# realtime_end                                             2022-10-16 00:00:00
# title                                Continued Claims (Insured Unemployment)
# observation_start                                        1967-01-07 00:00:00
# observation_end                                          2022-10-01 00:00:00
# frequency                                            Weekly, Ending Saturday
# frequency_short                                                            W
# units                                                                 Number
# units_short                                                           Number
# seasonal_adjustment                                      Seasonally Adjusted
# seasonal_adjustment_short                                                 SA
# last_updated                                       2022-10-13 07:33:03-05:00
# popularity                                                                71
# notes                      Continued claims, also referred to as insured ...
#
# series id                                                             U6RATE  \
# id                                                                    U6RATE
# realtime_start                                           2022-10-16 00:00:00
# realtime_end                                             2022-10-16 00:00:00
# title                      Total Unemployed, Plus All Persons Marginally ...
# observation_start                                        1994-01-01 00:00:00
# observation_end                                          2022-09-01 00:00:00
# frequency                                                            Monthly
# frequency_short                                                            M
# units                                                                Percent
# units_short                                                                %
# seasonal_adjustment                                      Seasonally Adjusted
# seasonal_adjustment_short                                                 SA
# last_updated                                       2022-10-07 07:44:03-05:00
# popularity                                                                71
# notes                      The series comes from the 'Current Population ...
#
# series id                                                              CCNSA  \
# id                                                                     CCNSA
# realtime_start                                           2022-10-16 00:00:00
# realtime_end                                             2022-10-16 00:00:00
# title                                Continued Claims (Insured Unemployment)
# observation_start                                        1967-01-07 00:00:00
# observation_end                                          2022-10-01 00:00:00
# frequency                                            Weekly, Ending Saturday
# frequency_short                                                            W
# units                                                                 Number
# units_short                                                           Number
# seasonal_adjustment                                  Not Seasonally Adjusted
# seasonal_adjustment_short                                                NSA
# last_updated                                       2022-10-13 07:33:03-05:00
# popularity                                                                32
# notes                      Continued claims, also referred to as insured ...
#
# series id                                                        LNS14000006  \
# id                                                               LNS14000006
# realtime_start                                           2022-10-16 00:00:00
# realtime_end                                             2022-10-16 00:00:00
# title                          Unemployment Rate - Black or African American
# observation_start                                        1972-01-01 00:00:00
# observation_end                                          2022-09-01 00:00:00
# frequency                                                            Monthly
# frequency_short                                                            M
# units                                                                Percent
# units_short                                                                %
# seasonal_adjustment                                      Seasonally Adjusted
# seasonal_adjustment_short                                                 SA
# last_updated                                       2022-10-07 07:44:03-05:00
# popularity                                                                68
# notes                      The series comes from the 'Current Population ...
#
# series id                                                          U6RATENSA  \
# id                                                                 U6RATENSA
# realtime_start                                           2022-10-16 00:00:00
# realtime_end                                             2022-10-16 00:00:00
# title                      Total Unemployed, Plus All Persons Marginally ...
# observation_start                                        1994-01-01 00:00:00
# observation_end                                          2022-09-01 00:00:00
# frequency                                                            Monthly
# frequency_short                                                            M
# units                                                                Percent
# units_short                                                                %
# seasonal_adjustment                                  Not Seasonally Adjusted
# seasonal_adjustment_short                                                NSA
# last_updated                                       2022-10-07 07:43:26-05:00
# popularity                                                                 8
# notes                      The series comes from the 'Current Population ...
#
# series id                                                        LNU03000000  \
# id                                                               LNU03000000
# realtime_start                                           2022-10-16 00:00:00
# realtime_end                                             2022-10-16 00:00:00
# title                                                     Unemployment Level
# observation_start                                        1948-01-01 00:00:00
# observation_end                                          2022-09-01 00:00:00
# frequency                                                            Monthly
# frequency_short                                                            M
# units                                                   Thousands of Persons
# units_short                                                Thous. of Persons
# seasonal_adjustment                                  Not Seasonally Adjusted
# seasonal_adjustment_short                                                NSA
# last_updated                                       2022-10-07 07:43:05-05:00
# popularity                                                                26
# notes                      The series comes from the 'Current Population ...
#
# series id                  ...  \
# id                         ...
# realtime_start             ...
# realtime_end               ...
# title                      ...
# observation_start          ...
# observation_end            ...
# frequency                  ...
# frequency_short            ...
# units                      ...
# units_short                ...
# seasonal_adjustment        ...
# seasonal_adjustment_short  ...
# last_updated               ...
# popularity                 ...
# notes                      ...
#
# series id                                                    LRHUTTTTDKA156S  \
# id                                                           LRHUTTTTDKA156S
# realtime_start                                           2022-10-16 00:00:00
# realtime_end                                             2022-10-16 00:00:00
# title                      Harmonised Unemployment - Monthly Rates: Total...
# observation_start                                        1983-01-01 00:00:00
# observation_end                                          2021-01-01 00:00:00
# frequency                                                             Annual
# frequency_short                                                            A
# units                                                                Percent
# units_short                                                                %
# seasonal_adjustment                                      Seasonally Adjusted
# seasonal_adjustment_short                                                 SA
# last_updated                                       2022-09-14 15:46:46-05:00
# popularity                                                                 2
# notes                      OECD descriptor ID: LRHUTTTT OECD unit ID: STS...
#
# series id                                                RICH051UR  \
# id                                                       RICH051UR
# realtime_start                                 2022-10-16 00:00:00
# realtime_end                                   2022-10-16 00:00:00
# title                      Unemployment Rate in Richmond, VA (MSA)
# observation_start                              1990-01-01 00:00:00
# observation_end                                2022-08-01 00:00:00
# frequency                                                  Monthly
# frequency_short                                                  M
# units                                                      Percent
# units_short                                                      %
# seasonal_adjustment                   Smoothed Seasonally Adjusted
# seasonal_adjustment_short                                      SSA
# last_updated                             2022-09-28 13:31:21-05:00
# popularity                                                       2
# notes                                                         None
#
# series id                                                  COLU913URN  \
# id                                                         COLU913URN
# realtime_start                                    2022-10-16 00:00:00
# realtime_end                                      2022-10-16 00:00:00
# title                      Unemployment Rate in Columbus, GA-AL (MSA)
# observation_start                                 1990-01-01 00:00:00
# observation_end                                   2022-08-01 00:00:00
# frequency                                                     Monthly
# frequency_short                                                     M
# units                                                         Percent
# units_short                                                         %
# seasonal_adjustment                           Not Seasonally Adjusted
# seasonal_adjustment_short                                         NSA
# last_updated                                2022-09-28 10:12:01-05:00
# popularity                                                          2
# notes                                                            None
#
# series id                                                         MIMACO9URN  \
# id                                                                MIMACO9URN
# realtime_start                                           2022-10-16 00:00:00
# realtime_end                                             2022-10-16 00:00:00
# title                                 Unemployment Rate in Macomb County, MI
# observation_start                                        1990-01-01 00:00:00
# observation_end                                          2022-08-01 00:00:00
# frequency                                                            Monthly
# frequency_short                                                            M
# units                                                                Percent
# units_short                                                                %
# seasonal_adjustment                                  Not Seasonally Adjusted
# seasonal_adjustment_short                                                NSA
# last_updated                                       2022-09-28 10:25:02-05:00
# popularity                                                                10
# notes                      These data come from the Current Population Su...
#
# series id                                                         NJMONM3URN  \
# id                                                                NJMONM3URN
# realtime_start                                           2022-10-16 00:00:00
# realtime_end                                             2022-10-16 00:00:00
# title                               Unemployment Rate in Monmouth County, NJ
# observation_start                                        1990-01-01 00:00:00
# observation_end                                          2022-08-01 00:00:00
# frequency                                                            Monthly
# frequency_short                                                            M
# units                                                                Percent
# units_short                                                                %
# seasonal_adjustment                                  Not Seasonally Adjusted
# seasonal_adjustment_short                                                NSA
# last_updated                                       2022-09-28 10:24:02-05:00
# popularity                                                                10
# notes                      These data come from the Current Population Su...
#
# series id                                                         TXGALV7URN  \
# id                                                                TXGALV7URN
# realtime_start                                           2022-10-16 00:00:00
# realtime_end                                             2022-10-16 00:00:00
# title                              Unemployment Rate in Galveston County, TX
# observation_start                                        1990-01-01 00:00:00
# observation_end                                          2022-08-01 00:00:00
# frequency                                                            Monthly
# frequency_short                                                            M
# units                                                                Percent
# units_short                                                                %
# seasonal_adjustment                                  Not Seasonally Adjusted
# seasonal_adjustment_short                                                NSA
# last_updated                                       2022-09-28 10:10:05-05:00
# popularity                                                                10
# notes                      These data come from the Current Population Su...
#
# series id                                                         WACLAR1URN  \
# id                                                                WACLAR1URN
# realtime_start                                           2022-10-16 00:00:00
# realtime_end                                             2022-10-16 00:00:00
# title                                  Unemployment Rate in Clark County, WA
# observation_start                                        1990-01-01 00:00:00
# observation_end                                          2022-08-01 00:00:00
# frequency                                                            Monthly
# frequency_short                                                            M
# units                                                                Percent
# units_short                                                                %
# seasonal_adjustment                                  Not Seasonally Adjusted
# seasonal_adjustment_short                                                NSA
# last_updated                                       2022-09-28 10:14:05-05:00
# popularity                                                                10
# notes                      These data come from the Current Population Su...
#
# series id                                                            PUAICNM  \
# id                                                                   PUAICNM
# realtime_start                                           2022-10-16 00:00:00
# realtime_end                                             2022-10-16 00:00:00
# title                      Pandemic Unemployment Assistance Initial Claim...
# observation_start                                        2020-04-04 00:00:00
# observation_end                                          2022-09-24 00:00:00
# frequency                                            Weekly, Ending Saturday
# frequency_short                                                            W
# units                                                                 Number
# units_short                                                           Number
# seasonal_adjustment                                  Not Seasonally Adjusted
# seasonal_adjustment_short                                                NSA
# last_updated                                       2022-10-03 07:33:07-05:00
# popularity                                                                10
# notes                      An initial claim is a claim filed by an unempl...
#
# series id                                                         OHBUTL2URN  \
# id                                                                OHBUTL2URN
# realtime_start                                           2022-10-16 00:00:00
# realtime_end                                             2022-10-16 00:00:00
# title                                 Unemployment Rate in Butler County, OH
# observation_start                                        1990-01-01 00:00:00
# observation_end                                          2022-08-01 00:00:00
# frequency                                                            Monthly
# frequency_short                                                            M
# units                                                                Percent
# units_short                                                                %
# seasonal_adjustment                                  Not Seasonally Adjusted
# seasonal_adjustment_short                                                NSA
# last_updated                                       2022-09-28 10:17:04-05:00
# popularity                                                                10
# notes                      These data come from the Current Population Su...
#
# series id                                                         PACHES5URN
# id                                                                PACHES5URN
# realtime_start                                           2022-10-16 00:00:00
# realtime_end                                             2022-10-16 00:00:00
# title                                Unemployment Rate in Chester County, PA
# observation_start                                        1990-01-01 00:00:00
# observation_end                                          2022-08-01 00:00:00
# frequency                                                            Monthly
# frequency_short                                                            M
# units                                                                Percent
# units_short                                                                %
# seasonal_adjustment                                  Not Seasonally Adjusted
# seasonal_adjustment_short                                                NSA
# last_updated                                       2022-09-28 10:18:03-05:00
# popularity                                                                10
# notes                      These data come from the Current Population Su...
#
# [15 rows x 1000 columns]
